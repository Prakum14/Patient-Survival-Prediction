# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakum14/Patient-Survival-Prediction/blob/main/Copy_of_M1_NB_MiniProject_2_Structured_Data_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification Programme in AI and MLOps
# ## A programme by IISc and TalentSprint
# ### Mini-Project Notebook: Structured Data Classification

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# To predict whether a patient has a heart disease.

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of the experiment, you will be able to
#
# * understand the Cleveland Clinic Foundation for Heart Disease dataset
# * pre-process this dataset
# * build a neural network architecture/model using Keras sequential or functional api
# * perform model training
# * perform inference on an unseen data
# * build a Gradio interface for this application

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to do structured data classification, starting from a raw
# CSV file. Our data includes both numerical and categorical features. We will do preprocessing to normalize the numerical features and vectorize the categorical
# ones.

# %% [markdown]
# ### Dataset
#
# [Our dataset](https://archive.ics.uci.edu/ml/datasets/heart+Disease) is provided by the
# Cleveland Clinic Foundation for Heart Disease.
# It's a CSV file with 303 rows. Each row contains information about a patient (a
# **sample**), and each column describes an attribute of the patient (a **feature**). We
# use the features to predict whether a patient has a heart disease (**binary
# classification**).
#
# Here's the description of each feature:
#
# Column| Description| Feature Type
# ------------|--------------------|----------------------
# Age | Age in years | Numerical
# Sex | (1 = male; 0 = female) | Categorical
# CP | Chest pain type (0, 1, 2, 3, 4) | Categorical
# Trestbpd | Resting blood pressure (in mm Hg on admission) | Numerical
# Chol | Serum cholesterol in mg/dl | Numerical
# FBS | fasting blood sugar in 120 mg/dl (1 = true; 0 = false) | Categorical
# RestECG | Resting electrocardiogram results (0, 1, 2) | Categorical
# Thalach | Maximum heart rate achieved | Numerical
# Exang | Exercise induced angina (1 = yes; 0 = no) | Categorical
# Oldpeak | ST depression induced by exercise relative to rest | Numerical
# Slope | Slope of the peak exercise ST segment | Numerical
# CA | Number of major vessels (0-3) colored by fluoroscopy | Both numerical & categorical
# Thal | 3 = normal; 6 = fixed defect; 7 = reversible defect | Categorical
# Target | Diagnosis of heart disease (1 = true; 0 = false) | Target

# %%
#@title Download the data
# !wget -qq https://cdn.iisc.talentsprint.com/AIandMLOps/Datasets/heart.csv
print("Data Downloaded Successfuly!!")
# !ls | grep '.csv'
# Out:
# Data Downloaded Successfuly!!
# heart.csv

# %% [markdown]
# ## Grading = 10 Points

# %% [markdown]
# ### Import Required Packages

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Load the data and pre-process it [3 Marks]

# %% [markdown]
# ### Load data into a Pandas dataframe
#
# Hint:: pd.read_csv

# %%
file_url = "/content/heart.csv"
## YOUR CODE HERE

data = pd.read_csv(file_url)

# %% [markdown]
# Check the shape of the dataset:

# %%
## YOUR CODE HERE

data.shape
# Out:
# (303, 14)

# %% [markdown]
# Check the preview of a few samples:
#
# Hint:: head()

# %%
## YOUR CODE HERE

data.head(50)
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   1       145   233    1        2      150      0      2.3
# 1    67    1   4       160   286    0        2      108      1      1.5
# 2    67    1   4       120   229    0        2      129      1      2.6
# 3    37    1   3       130   250    0        0      187      0      3.5
# 4    41    0   2       130   204    0        2      172      0      1.4
# 5    56    1   2       120   236    0        0      178      0      0.8
# 6    62    0   4       140   268    0        2      160      0      3.6
# 7    57    0   4       120   354    0        0      163      1      0.6
# 8    63    1   4       130   254    0        2      147      0      1.4
# 9    53    1   4       140   203    1        2      155      1      3.1
# 10   57    1   4       140   192    0        0      148      0      0.4
# 11   56    0   2       140   294    0        2      153      0      1.3
# 12   56    1   3       130   256    1        2      142      1      0.6
# 13   44    1   2       120   263    0        0      173      0      0.0
# 14   52    1   3       172   199    1        0      162      0      0.5
# 15   57    1   3       150   168    0        0      174      0      1.6
# 16   48    1   2       110   229    0        0      168      0      1.0
# 17   54    1   4       140   239    0        0      160      0      1.2
# 18   48    0   3       130   275    0        0      139      0      0.2
# 19   49    1   2       130   266    0        0      171      0      0.6
# 20   64    1   1       110   211    0        2      144      1      1.8
# 21   58    0   1       150   283    1        2      162      0      1.0
# 22   58    1   2       120   284    0        2      160      0      1.8
# 23   58    1   3       132   224    0        2      173      0      3.2
# 24   60    1   4       130   206    0        2      132      1      2.4
# 25   50    0   3       120   219    0        0      158      0      1.6
# 26   58    0   3       120   340    0        0      172      0      0.0
# 27   66    0   1       150   226    0        0      114      0      2.6
# 28   43    1   4       150   247    0        0      171      0      1.5
# 29   40    1   4       110   167    0        2      114      1      2.0
# 30   69    0   1       140   239    0        0      151      0      1.8
# 31   60    1   4       117   230    1        0      160      1      1.4
# 32   64    1   3       140   335    0        0      158      0      0.0
# 33   59    1   4       135   234    0        0      161      0      0.5
# 34   44    1   3       130   233    0        0      179      1      0.4
# 35   42    1   4       140   226    0        0      178      0      0.0
# 36   43    1   4       120   177    0        2      120      1      2.5
# 37   57    1   4       150   276    0        2      112      1      0.6
# 38   55    1   4       132   353    0        0      132      1      1.2
# 39   61    1   3       150   243    1        0      137      1      1.0
# 40   65    0   4       150   225    0        2      114      0      1.0
# 41   65    0   3       155   269    0        0      148      0      0.8
# 42   67    1   4       125   254    1        0      163      0      0.2
# 43   62    1   4       120   267    0        0       99      1      1.8
# 44   65    1   4       110   248    0        2      158      0      0.6
# 45   44    1   4       110   197    0        2      177      0      0.0
# 46   65    0   3       160   360    0        2      151      0      0.8
# 47   60    1   4       125   258    0        2      141      1      2.8
# 48   51    0   3       140   308    0        2      142      0      1.5
# 49   48    1   2       130   245    0        2      180      0      0.2
#
#     slope  ca        thal  target
# 0       3   0       fixed       0
# 1       2   3      normal       1
# 2       2   2  reversible       0
# 3       3   0      normal       0
# 4       1   0      normal       0
# 5       1   0      normal       0
# 6       3   2      normal       1
# 7       1   0      normal       0
# 8       2   1  reversible       1
# 9       3   0  reversible       0
# 10      2   0       fixed       0
# 11      2   0      normal       0
# 12      2   1       fixed       1
# 13      1   0  reversible       0
# 14      1   0  reversible       0
# 15      1   0      normal       0
# 16      3   0  reversible       0
# 17      1   0      normal       0
# 18      1   0      normal       0
# 19      1   0      normal       0
# 20      2   0      normal       0
# 21      1   0      normal       0
# 22      2   0      normal       0
# 23      1   2  reversible       1
# 24      2   2  reversible       1
# 25      2   0      normal       0
# 26      1   0      normal       0
# 27      3   0      normal       0
# 28      1   0      normal       0
# 29      2   0  reversible       1
# 30      1   2      normal       0
# 31      1   2  reversible       1
# 32      1   0      normal       0
# 33      2   0  reversible       0
# 34      1   0      normal       0
# 35      1   0      normal       0
# 36      2   0  reversible       1
# 37      2   1       fixed       0
# 38      2   1  reversible       1
# 39      2   0      normal       0
# 40      2   3  reversible       1
# 41      1   0      normal       0
# 42      2   2  reversible       1
# 43      2   2  reversible       0
# 44      1   2       fixed       0
# 45      1   1      normal       0
# 46      1   0      normal       0
# 47      2   1  reversible       0
# 48      1   1      normal       0
# 49      2   0      normal       0

# %% [markdown]
# Draw some inference from the data. What does the target column indicate?
#
# The last column, "target", indicates whether the patient has a heart disease (1) or not
# (0).

# %% [markdown]
# ### Missing values

# %%
# Check if any missing values is present
## YOUR CODE HERE

print(data.isna().sum() > 0 )
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %% [markdown]
# ### Show the unique values present in each categorical columns
#
# - Remove the rows which has '1' and '2' as values in `thal` column

# %%
# Show all the columns in dataframe
## YOUR CODE HERE

data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Print the unique values present in each categorical columns

categorical_cols = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'ca', 'thal']

## YOUR CODE HERE
data[categorical_cols].nunique()
# Out:
# sex        2
# cp         5
# fbs        2
# restecg    3
# exang      2
# ca         4
# thal       5
# dtype: int64

# %%
# Print the unique values present in each categorical columns along with their counts

for cat_col in categorical_cols:
  print(data[cat_col].value_counts())
# Out:
# sex
# 1    205
# 0     98
# Name: count, dtype: int64
# cp
# 4    142
# 3     84
# 2     49
# 1     24
# 0      4
# Name: count, dtype: int64
# fbs
# 0    258
# 1     45
# Name: count, dtype: int64
# restecg
# 0    149
# 2    146
# 1      8
# Name: count, dtype: int64
# exang
# 0    204
# 1     99
# Name: count, dtype: int64
# ca
# 0    176
# 1     67
# 2     40
# 3     20
# Name: count, dtype: int64
# thal
# normal        168
# reversible    115
# fixed          18
# 1               1
# 2               1
# Name: count, dtype: int64

# %% [markdown]
# - Remove the rows which has '1' and '2' as values in `thal` column

# %%
# Find indices of the rows which has '1', '2' as values in `thal` column

idx = data.loc[(data['thal']=='1') | (data['thal']=='2')].index
idx
# Out:
# Index([247, 252], dtype='int64')

# %%
# Drop the above indexed rows

data.drop(index=idx,inplace=True)

# %%
# Recheck the unique values present in each categorical columns

for cat_col in categorical_cols:
  print(data[cat_col].value_counts())
# Out:
# sex
# 1    204
# 0     97
# Name: count, dtype: int64
# cp
# 4    142
# 3     84
# 2     49
# 1     23
# 0      3
# Name: count, dtype: int64
# fbs
# 0    257
# 1     44
# Name: count, dtype: int64
# restecg
# 0    147
# 2    146
# 1      8
# Name: count, dtype: int64
# exang
# 0    202
# 1     99
# Name: count, dtype: int64
# ca
# 0    176
# 1     66
# 2     39
# 3     20
# Name: count, dtype: int64
# thal
# normal        168
# reversible    115
# fixed          18
# Name: count, dtype: int64

# %% [markdown]
# ### Convert the categorical values present in `thal` column to numerical labels
#
# Hint: Create a dictionary mapping

# %%
thal_dict={'normal':0 , 'fixed':1 , 'reversible':2}
data['thal']=data['thal'].map(thal_dict)

# %% [markdown]
# ### Split the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

## YOUR CODE HERE (perform stratified sampling/splitting)
x_train,x_test,y_train,y_test = train_test_split(data.drop('target',axis=1),data['target'],test_size=0.2,stratify=data['target'],random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((240, 13), (61, 13), (240,), (61,))

# %% [markdown]
# ### Scale the numerical features

# %%
numerical_cols = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'slope']

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_train[numerical_cols]=scaler.fit_transform(x_train[numerical_cols])
x_test[numerical_cols]=scaler.transform(x_test[numerical_cols])

# %%
x_train.head()
# Out:
#           age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 101  1.362636    0   3 -0.963595  5.868071    0        2  0.498048      0
# 55  -0.282397    1   2 -0.679558  1.414375    0        0  1.014755      0
# 107  0.594954    1   4  0.456589  0.818064    0        2  0.928637      0
# 183  0.156278    1   4 -0.111484  0.631717    1        2 -1.956310      1
# 17  -0.063060    1   4  0.456589 -0.188211    0        0  0.498048      0
#
#       oldpeak     slope  ca  thal
# 101  0.429344  0.691529   0     2
# 55  -0.744452 -0.935599   0     0
# 107  0.093973  0.691529   2     2
# 183  0.429344  2.318657   0     2
# 17   0.093973 -0.935599   0     0

# %% [markdown]
# ## Building the model [3 Marks]

# %% [markdown]
# * Use tf.keras.layers.Input() for input layer
# * Add dense layers
# * Add dropout layers
# * Add a classification layer at the end

# %%
from keras import Input

# %%
input_shape=x_train.shape[1]

model_seq = keras.Sequential(name="sequential_model")
model_seq.add(tf.keras.layers.Input(shape=(input_shape,)))   #specifying the input here
model_seq.add(keras.layers.Dense(64, activation=tf.nn.relu, name="first_layer"))
model_seq.add(keras.layers.Dropout(0.2))
model_seq.add(keras.layers.Dense(10, activation=tf.nn.relu, name="second_layer"))
model_seq.add(keras.layers.Dropout(0.2))
model_seq.add(keras.layers.Dense(1, activation=tf.nn.sigmoid, name="final_layer"))
model_seq.summary()
# Out:
# Model: "sequential_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ first_layer (Dense)                  │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ second_layer (Dense)                 │ (None, 10)                  │             650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ final_layer (Dense)                  │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,557 (6.08 KB)
#  Trainable params: 1,557 (6.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile model with 'adam' optimizer, appropriate loss and metric

model_seq.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy','precision','recall'])

# %%
# Perform training
epochs=50
batch_size=32
validation_split=0.2

model_seq.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_split=validation_split)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.5531 - loss: 0.6976 - precision: 0.3144 - recall: 0.5446 - val_accuracy: 0.7708 - val_loss: 0.6359 - val_precision: 0.6000 - val_recall: 0.6429
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7305 - loss: 0.6093 - precision: 0.5407 - recall: 0.5459 - val_accuracy: 0.7500 - val_loss: 0.6069 - val_precision: 0.6250 - val_recall: 0.3571
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7281 - loss: 0.5862 - precision: 0.5204 - recall: 0.3424 - val_accuracy: 0.7292 - val_loss: 0.5792 - val_precision: 0.6000 - val_recall: 0.2143
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8039 - loss: 0.5311 - precision: 0.6473 - recall: 0.5204 - val_accuracy: 0.7292 - val_loss: 0.5517 - val_precision: 0.6000 - val_recall: 0.2143
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7455 - loss: 0.5485 - precision: 0.5929 - recall: 0.3074 - val_accuracy: 0.7708 - val_loss: 0.5249 - val_precision: 0.7143 - val_recall: 0.3571
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7737 - loss: 0.5152 - precision: 0.6460 - recall: 0.4287 - val_accuracy: 0.7917 - val_loss: 0.4959 - val_precision: 0.7500 - val_recall: 0.4286
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8735 - loss: 0.2964 - precision: 0.7726 - recall: 0.8010 - val_accuracy: 0.8125 - val_loss: 0.4093 - val_precision: 0.6923 - val_recall: 0.6429

# %%
# Performance on test set

model_seq.evaluate(x_test,y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8381 - loss: 0.3986 - precision: 0.7143 - recall: 0.6303
# [0.4191562533378601,
#  0.8196721076965332,
#  0.7142857313156128,
#  0.5882353186607361]

# %% [markdown]
# ## Inference on new data [1 Mark]
#
# To get a prediction for a new sample, you can simply call `model.predict()`.

# %%
# Inference on new data

sample = {
    "age": 60,
    "sex": 1,
    "cp": 1,
    "trestbps": 145,
    "chol": 233,
    "fbs": 1,
    "restecg": 2,
    "thalach": 150,
    "exang": 0,
    "oldpeak": 2.3,
    "slope": 3,
    "ca": 0,
    "thal": 0,
}
sample_df=pd.DataFrame(sample,index=[0])
sample_df[numerical_cols]=scaler.transform(sample_df[numerical_cols])

# %%
sample_df
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0  0.594954    1   1  0.740626 -0.300019    1        2  0.067459      0
#
#     oldpeak     slope  ca  thal
# 0  1.016241  2.318657   0     0

# %%
out = model_seq.predict(sample_df)
if out < 0.5:
    print ("No")
else:
    print("Yes")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# No

# %% [markdown]
# ## Gradio Implementation [3 Marks]
#
# Create a Gradio interface for this `Heart Disease Prediction` application. For the feature values given by the user as input, perform predcition using the trained model, and return the result back to user.
#
# Make use of gradio elements such as Textbox, Radio buttons, etc.

# %%
# %%capture
# !pip -q install gradio

# %%
import gradio
import gradio as gr

# %%
# UI - Input components
## YOUR CODE HERE ...

# import gradio as gr

def greet(age, male, female, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal):
    if male:
        sex = 1
    if female:
        sex = 0
    sample = {
        "age": age,
        "sex": sex,
        "cp": cp,
        "trestbps": trestbps,
        "chol": chol,
        "fbs": fbs,
        "restecg": restecg,
        "thalach": thalach,
        "exang": exang,
        "oldpeak": oldpeak,
        "slope": slope,
        "ca": ca,
        "thal": thal,
    }
    sample_df=pd.DataFrame(sample,index=[0])
    sample_df[numerical_cols]=scaler.transform(sample_df[numerical_cols])

# UI - Output component
## YOUR CODE HERE ...
    out = model_seq.predict(sample_df)

    if out < 0.5:
        return("No Heart disease")
    else:
        return("The patient has Heart disease. Admit immediately!!")



demo = gr.Interface(
    fn=greet,
    inputs=["text", "checkbox", "checkbox", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text", "text"],
    outputs=["text"],
)


    # "age": 60,
    # "sex": 1,
    # "cp": 1,
    # "trestbps": 145,
    # "chol": 233,
    # "fbs": 1,
    # "restecg": 2,
    # "thalach": 150,
    # "exang": 0,
    # "oldpeak": 2.3,
    # "slope": 3,
    # "ca": 0,
    # "thal": 0,


demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://35f0eff19df52b132e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://35f0eff19df52b132e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-94ad537a5cde> in <cell line: 1>()
# ----> 1 age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal
#
# NameError: name 'age' is not defined

# %%
# Label prediction function

## YOUR CODE HERE

# %%
# Create Gradio interface object and launch it with (share=True)

## YOUR CODE HERE
